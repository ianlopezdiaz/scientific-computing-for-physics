# %% [markdown]
# # 02 - Numerical Integration

# %% [markdown]
# ## 1. Physical Motivation
# _(placeholder)_

# %% [markdown]
# ## 2. Theory
# _(placeholder)_

# %% [markdown]
# ## 3. Analytical Solution
# _(placeholder)_

# %% [markdown]
# ## 4. Numerical Implementation
# _(placeholder)_

# %%
import numpy as np

# %% [markdown]
# ## 5. Visualization
# _(placeholder)_

# %% [markdown]
# ## 6. Exercises
# _(placeholder)_

# %% [markdown]
# ## 7. Extensions
# _(placeholder)_
